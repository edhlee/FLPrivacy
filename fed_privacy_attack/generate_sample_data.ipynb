# %%
import numpy as np
import pickle
# Data loading and processing
# def load_data(site_range, file_prefix, data_type):
# data_x_all, data_y_all = [], []
site_range = 21
data_type = "train"
file_prefix = "train_val_split_variation_8020_0"
for site_idx in range(site_range):
    data = np.load(f"{file_prefix}/CovidData2022_cohort{site_idx}{data_type}.npy", allow_pickle=True)
    data_x = data[f"c{site_idx}_x"]
    data_y = data[f"c{site_idx}_y"]

    # sample randomly 10% of the data for each site
    sample_size = int(len(data_x) * 0.1)
    sample_idx = np.random.choice(len(data_x), sample_size, replace=False)
    data_x = data_x[sample_idx]
    data_y = data_y[sample_idx]

    # save  as a pickle file back into the same folder
    all_data = {}
    all_data[f"c{site_idx}_x"] =  data_x
    all_data[f"c{site_idx}_y"] =  data_y


    
    file_prefix2 = "data"
    with open(f"{file_prefix2}/CovidData2022_cohort{site_idx}{data_type}.npy", 'wb') as filehandle:
        temp = pickle.dump(all_data, filehandle, protocol=4)
        

    print(data_x.shape)
    print(data_y.shape)
# train_x_all, train_y_all = load_data(NUM_SITES, "train_val_split_variation_8020_0", "train")
# Out:
# (312, 256, 256, 24, 1)
# (312,)
# (22, 256, 256, 24, 1)
# (22,)
# (4, 256, 256, 24, 1)
# (4,)
# (17, 256, 256, 24, 1)
# (17,)
# (5, 256, 256, 24, 1)
# (5,)
# (18, 256, 256, 24, 1)
# (18,)
# (4, 256, 256, 24, 1)
# (4,)
# (6, 256, 256, 24, 1)
# (6,)
# (23, 256, 256, 24, 1)
# (23,)
# (57, 256, 256, 24, 1)
# (57,)
# (13, 256, 256, 24, 1)
# (13,)
# (83, 256, 256, 24, 1)
# (83,)
# (20, 256, 256, 24, 1)
# (20,)
# (3, 256, 256, 24, 1)
# (3,)
# (17, 256, 256, 24, 1)
# (17,)
# (32, 256, 256, 24, 1)
# (32,)
# (6, 256, 256, 24, 1)
# (6,)
# (12, 256, 256, 24, 1)
# (12,)
# (60, 256, 256, 24, 1)
# (60,)
# (15, 256, 256, 24, 1)
# (15,)
# (102, 256, 256, 24, 1)
# (102,)

# %%
import numpy as np
import pickle
# Data loading and processing
# def load_data(site_range, file_prefix, data_type):
# data_x_all, data_y_all = [], []
site_range = 21
data_type = "test"
file_prefix = "train_val_split_variation_8020_0"
for site_idx in range(site_range):
    data = np.load(f"{file_prefix}/CovidData2022_cohort{site_idx}{data_type}.npy", allow_pickle=True)
    data_x = data[f"c{site_idx}_x"]
    data_y = data[f"c{site_idx}_y"]

    # sample randomly 10% of the data for each site
    sample_size = int(len(data_x) * 0.2)
    sample_idx = np.random.choice(len(data_x), sample_size, replace=False)
    data_x = data_x[sample_idx]
    data_y = data_y[sample_idx]

    # save  as a pickle file back into the same folder
    all_data = {}
    all_data[f"c{site_idx}_x"] =  data_x
    all_data[f"c{site_idx}_y"] =  data_y


    
    file_prefix2 = "data"
    with open(f"{file_prefix2}/CovidData2022_cohort{site_idx}{data_type}.npy", 'wb') as filehandle:
        temp = pickle.dump(all_data, filehandle, protocol=4)
        

    print(data_x.shape)
    print(data_y.shape)
# train_x_all, train_y_all = load_data(NUM_SITES, "train_val_split_variation_8020_0", "train")
# Out:
# (208, 256, 256, 24, 1)
# (208,)
# (15, 256, 256, 24, 1)
# (15,)
# (3, 256, 256, 24, 1)
# (3,)
# (11, 256, 256, 24, 1)
# (11,)
# (3, 256, 256, 24, 1)
# (3,)
# (12, 256, 256, 24, 1)
# (12,)
# (3, 256, 256, 24, 1)
# (3,)
# (4, 256, 256, 24, 1)
# (4,)
# (16, 256, 256, 24, 1)
# (16,)
# (38, 256, 256, 24, 1)
# (38,)
# (8, 256, 256, 24, 1)
# (8,)
# (55, 256, 256, 24, 1)
# (55,)
# (13, 256, 256, 24, 1)
# (13,)
# (2, 256, 256, 24, 1)
# (2,)
# (12, 256, 256, 24, 1)
# (12,)
# (21, 256, 256, 24, 1)
# (21,)
# (4, 256, 256, 24, 1)
# (4,)
# (8, 256, 256, 24, 1)
# (8,)
# (40, 256, 256, 24, 1)
# (40,)
# (10, 256, 256, 24, 1)
# (10,)
# (68, 256, 256, 24, 1)
# (68,)
